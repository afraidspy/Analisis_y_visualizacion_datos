# %%
## Dataset Airbnb

# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")
df
# Out:
#                         id                                            nombre  \
# 0                    35797                                       Villa Dante
# 1                    44616                                      Condesa Haus
# 2                    56074              Great space in historical San Rafael
# 3                    67703                 2 bedroom apt. deco bldg, Condesa
# 4                    70644  Beautiful light Studio Coyoacan- full equipped !
# ...                    ...                                               ...
# 27046  1518356968266486778                                       Suite Frida
# 27047  1518388105556721163   Habitación a un costado de Ciudad Universitaria
# 27048  1518433354720281854                 Espacioso departamento en Anzures
# 27049  1518462568893975567                                 Casa Roma Baja 05
# 27050  1518561444972990747       Departamento con Terraza privada Roma Norte
#
# ...

# %%
df.shape
# Out:
# (27051, 18)

# %%
df.columns
# Out:
# Index(['id', 'nombre', 'id_anfitrion', 'nombre_anfitrion', 'grupo_colonia',
#        'colonia', 'latitud', 'longitud', 'tipo_habitacion', 'precio',
#        'noches_minimas', 'numero_resenas', 'ultima_resena', 'resenas_por_mes',
#        'propiedades_anfitrion', 'disponibilidad_365', 'number_of_reviews_ltm',
#        'license'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27051 entries, 0 to 27050
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     27051 non-null  int64
#  1   nombre                 27051 non-null  object
#  2   id_anfitrion           27051 non-null  int64
#  3   nombre_anfitrion       27045 non-null  object
#  4   grupo_colonia          0 non-null      float64
#  5   colonia                27051 non-null  object
#  6   latitud                27051 non-null  float64
#  7   longitud               27051 non-null  float64
#  8   tipo_habitacion        27051 non-null  object
#  9   precio                 23567 non-null  float64
#  10  noches_minimas         27051 non-null  int64
#  11  numero_resenas         27051 non-null  int64
#  12  ultima_resena          23650 non-null  object
#  13  resenas_por_mes        23650 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id  id_anfitrion  grupo_colonia       latitud      longitud  \
# count  2.705100e+04  2.705100e+04            0.0  27051.000000  27051.000000
# mean   7.003556e+17  2.429439e+08            NaN     19.405490    -99.165385
# std    5.702714e+17  2.062579e+08            NaN      0.042390      0.033535
# min    3.579700e+04  7.365000e+03            NaN     19.177848    -99.339630
# 25%    4.410472e+07  5.621443e+07            NaN     19.392489    -99.178499
# 50%    8.307368e+17  1.766835e+08            NaN     19.415390    -99.167100
# 75%    1.217382e+18  4.288830e+08            NaN     19.432015    -99.153731
# max    1.518561e+18  7.208445e+08            NaN     19.561010    -98.963360
#
#               precio  noches_minimas  numero_resenas  resenas_por_mes  \
# count   23567.000000    27051.000000    27051.000000     23650.000000
# mean     1792.540841        4.580866       53.777679         1.854855
# ...
